# %%
system_prompt = """
You are an experienced instructor for a graduate-level data science course in an engineering program. 
You have experience creating assessments for the course. Your task is to assess the question based on certain evaluation criteria given. Output only the answer and nothing else and only from the options

Evaluation Criteria:
 - Understandable: Could you understand what the question is asking? Please check if the question is composed in such a way that the question can be comprehended easily; Options: yes, no
 - TopicRelated: Is the question related to the course topic given? Please check if the question pertains directly to the key themes or concepts of the given course topic; Options: yes, no, NA
 - Grammatical: Is the question grammatically well-formed? Please check if the question adheres to the rules of English grammar; Options: yes, no, NA
 - Clear: Is it clear what the question asks for? Please check if the phrasing of the question leaves any doubt about what is being asked. Also check if there's vagueness in the making it difficult to answer the question; Options: yes, more_or_less, no, NA
 - Rephrase: Could you rephrase the question to make it clearer and error-free? Please check if this question, as it is posed, can be reworded to improve clarity or correct errors while preserving its original meaning. If your answer is yes, rephrase the question; Options: yes, no, NA
 - Answerable: Can students answer the question with the information or context provided within? Please check if the question is answerable using the knowledge that the students are expected to have from the course material on the topic provided within the question itself. The course curriculum is a standard graduate-level data science course curriculum; Options: yes, no, NA
 - Central: Do you think being able to answer the question is important to work on the course topic given? Please check if answering the question requires an understanding of the key concepts that are critical to the subject matter; Options: yes, no, NA
 - WouldYouUseIt: If you were a teacher teaching the course topic, would you use this question or the rephrased version in the course? Please check if you would consider the question to be of practical value for teaching and learning, and if it is something that would be chosen for inclusion in course materials or assessments; Options: yes, maybe, no, NA
 - SkillLevel: What is the Bloom’s skill associated with the question? This should be aligned with the complexity and type of cognitive process assessed in the question, from simple recall of facts (remember) to more complex tasks like synthesizing new ideas (create); Options: remember, understand, apply, analyze, evaluate, create, NA
"""

# %%
user_prompt_template = """
Please make sure you read and understand the following content and instructions carefully. Evaluate it according to the instructions.

Question: {question}

Course topic: {topic}

Evaluation instructions: {Hierarchical_evaluation_description}
"""

# %%
metrics = ["Understandable", "TopicRelated", "Grammatical", "Clear", "Rephrase", "Answerable", "Central", "WouldYouUseIt", "SkillLevel"]

# %%
from ollama_interface import chat_with_model

# %%
default_options = {
    "temperature": 0.0,
    "top_p": 0.9,
    "top_k": 40,
    "num_predict": -1,
    "presence_penalty": 0.0,
    "frequency_penalty": 0.0,
    "repeat_penalty": 1.1,
    "stop": [],
    "seed": None,
    "mirostat": 0,
    "mirostat_tau": 5.0,
    "mirostat_eta": 0.1,
    "grammar": None
}

# %%
def fill_prompt_template(template_text, values_dict):
    for key, value in values_dict.items():
        if value is None:
            value = "None"
        template_text = template_text.replace(f"{{{key}}}", value)
    return template_text

# %%
def llm_inference(question, topic, metric, model = "llama3.3:latest"):
    template_values = {
        "question": question,
        "topic": topic,
        "Hierarchical_evaluation_description": f"Evaluate only the metric {metric}"
    }
    filled_prompt = fill_prompt_template(user_prompt_template, template_values)
    messages = [
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": filled_prompt}
    ]
    
    try:
        response = chat_with_model(
            model_name=model,
            messages=messages,
            options=default_options
        )
        answer = response["message"]["content"].strip()
    except Exception as e:
        answer = f"Error: {e}"
    
    return answer

# %%
TOPICS = [
    "Decision Tree Models",
    "Training, Validation, and Testing of Machine Learning Models",
    "Gradient Boosted Tree Models",
    "Linear Regression, Logistic Regression, and Multilayer Perceptron",
    "Stochastic Gradient Descent",
    "Backpropagation",
    "Foundations of Computer Vision and Convolutional Neural Networks",
    "Transfer Learning for Computer Vision",
    "Image Segmentation and Object Detection",
    "Data Pre-processing for Natural Language Processing Tasks",
    "Bag of Words Approach and Word Embedding",
    "Attention Mechanism in Transformers",
    "Neural Machine Translation using Transformers",
    "Encoder, Decoder, and Sequence-to-Sequence Transformers",
    "Pretraining, Finetuning, and Reinforcement Learning with Human Feedback",
    "Prompt Engineering and Chain of Thought Prompting",
    "Natural Language Processing Tasks and Transformer Architectures Used for the Tasks"
]

# %%
def get_merged_cell_value(ws, cell):
    # Check if the cell is part of a merged range
    for merged_range in ws.merged_cells.ranges:
        if cell.coordinate in merged_range:
            # Return the value from the top-left cell of the merged range
            return ws.cell(merged_range.min_row, merged_range.min_col).value
    return cell.value

# %%
import re

def clean_multi_task_outputs(outputs):
    """
    Cleans a list of 9 LLM outputs by checking the beginning of each response
    against predefined valid options for each task. Only exact matches with optional
    trailing punctuation are accepted.

    Parameters:
    - outputs (list of str): Raw outputs from the LLM for 9 tasks.

    Returns:
    - list of str: Cleaned outputs with valid labels or "Did not answer".
    """
    if len(outputs) != 9:
        raise ValueError("Expected exactly 9 outputs.")

    valid_options = [
        ["yes", "no"],  # 1
        ["yes", "no", "na"],  # 2
        ["yes", "no", "na"],  # 3
        ["yes", "more_or_less", "no", "na"],  # 4
        ["yes", "no", "na"],  # 5
        ["yes", "no", "na"],  # 6
        ["yes", "no", "na"],  # 7
        ["yes", "maybe", "no", "na"],  # 8
        ["remember", "understand", "apply", "analyze", "evaluate", "create", "na"],  # 9
    ]

    cleaned_outputs = []
    for output, options in zip(outputs, valid_options):
        output_lower = output.lower().strip()[:min(100,len(output))]

        # Extract the first few words (in case it's a phrase like "more_or_less")
        # Strip common trailing punctuation for matching
        first_part = re.split(r'\s|[.,!?]', output_lower)[0].strip(",.!?")

        matched = None
        for opt in options:
            if first_part == opt:
                matched = opt
                break

        cleaned_outputs.append(matched if matched else "Did not answer")

    return cleaned_outputs

# %%
import openpyxl

# Load the workbook
workbook_path = 'Questions_generated.xlsx'  # Replace with your actual file path
wb = openpyxl.load_workbook(workbook_path)

# %% [markdown]
# ## granite4:latest

# %%
import csv
model = "granite4:latest"
# Iterate over all sheets in the workbook
for sheet_name in wb.sheetnames:
    ws = wb[sheet_name]
    print(f"\nSheet: {sheet_name}")
    with open(f"{sheet_name}_{model}.csv", "w", newline="") as file:
        writer = csv.writer(file)
    
        for row in ws.iter_rows(min_row=2, max_col=4, max_row = 715):
            index = row[0].value  
            prompt = row[1].value 
            col_b_cell = row[1] if len(row) > 1 else None  
            prompt = get_merged_cell_value(ws, col_b_cell) if col_b_cell else None
            question = row[3].value  
            topic = [topic for topic in TOPICS if topic in prompt][0]
            print(f"Index {index} Topic: {topic}")
            temp = []
            for metric in metrics:
                temp.append(llm_inference(question,topic,metric, model = model))
            temp = clean_multi_task_outputs(temp)
            writer.writerow(temp)
# Out:
# Sheet: PS1
# Index 1 Topic: Decision Tree Models
# Index 2 Topic: Decision Tree Models
# Index 3 Topic: Decision Tree Models
# Index 4 Topic: Decision Tree Models
# Index 5 Topic: Decision Tree Models
# Index 6 Topic: Decision Tree Models
# Index 7 Topic: Decision Tree Models
# Index 8 Topic: Decision Tree Models
# Index 9 Topic: Decision Tree Models
# Index 10 Topic: Decision Tree Models
# Index 12 Topic: Decision Tree Models
# Index 13 Topic: Decision Tree Models
# Index 14 Topic: Decision Tree Models
# Index 15 Topic: Decision Tree Models
# Index 16 Topic: Decision Tree Models
# Index 17 Topic: Decision Tree Models
# Index 18 Topic: Decision Tree Models
# Index 19 Topic: Decision Tree Models
# Index 20 Topic: Decision Tree Models
# Index 21 Topic: Decision Tree Models
# Index 22 Topic: Decision Tree Models
# Index 23 Topic: Decision Tree Models
# Index 24 Topic: Decision Tree Models
# Index 25 Topic: Decision Tree Models
# Index 26 Topic: Decision Tree Models
# Index 27 Topic: Decision Tree Models
# Index 28 Topic: Decision Tree Models
# Index 29 Topic: Decision Tree Models
# Index 30 Topic: Decision Tree Models
# Index 31 Topic: Decision Tree Models
# Index 32 Topic: Decision Tree Models
# Index 33 Topic: Decision Tree Models
# Index 34 Topic: Decision Tree Models
# Index 35 Topic: Decision Tree Models
# Index 36 Topic: Decision Tree Models
# Index 37 Topic: Decision Tree Models
# Index 38 Topic: Decision Tree Models
# Index 39 Topic: Decision Tree Models
# Index 40 Topic: Decision Tree Models
# Index 41 Topic: Decision Tree Models
# Index 42 Topic: Decision Tree Models
# Index 43 Topic: Decision Tree Models
# Index 44 Topic: Decision Tree Models
# Index 45 Topic: Decision Tree Models
# Index 46 Topic: Decision Tree Models
# Index 47 Topic: Decision Tree Models
# Index 48 Topic: Decision Tree Models
# Index 49 Topic: Training, Validation, and Testing of Machine Learning Models
# Index 50 Topic: Training, Validation, and Testing of Machine Learning Models
# Index 51 Topic: Training, Validation, and Testing of Machine Learning Models
# Index 52 Topic: Training, Validation, and Testing of Machine Learning Models
# Index 53 Topic: Training, Validation, and Testing of Machine Learning Models
# Index 54 Topic: Training, Validation, and Testing of Machine Learning Models
# Index 55 Topic: Training, Validation, and Testing of Machine Learning Models
# Index 56 Topic: Training, Validation, and Testing of Machine Learning Models
# Index 57 Topic: Training, Validation, and Testing of Machine Learning Models
# Index 58 Topic: Training, Validation, and Testing of Machine Learning Models
# Index 59 Topic: Training, Validation, and Testing of Machine Learning Models
# Index 60 Topic: Training, Validation, and Testing of Machine Learning Models
# Index 61 Topic: Training, Validation, and Testing of Machine Learning Models
# Index 62 Topic: Training, Validation, and Testing of Machine Learning Models
# Index 63 Topic: Training, Validation, and Testing of Machine Learning Models
# Index 64 Topic: Training, Validation, and Testing of Machine Learning Models
# Index 65 Topic: Training, Validation, and Testing of Machine Learning Models
# Index 66 Topic: Training, Validation, and Testing of Machine Learning Models
# Index 67 Topic: Training, Validation, and Testing of Machine Learning Models
# Index 68 Topic: Training, Validation, and Testing of Machine Learning Models
# Index 69 Topic: Training, Validation, and Testing of Machine Learning Models
# Index 70 Topic: Training, Validation, and Testing of Machine Learning Models
# Index 71 Topic: Training, Validation, and Testing of Machine Learning Models
# Index 72 Topic: Training, Validation, and Testing of Machine Learning Models
# Index 73 Topic: Training, Validation, and Testing of Machine Learning Models
# Index 74 Topic: Training, Validation, and Testing of Machine Learning Models
# Index 75 Topic: Training, Validation, and Testing of Machine Learning Models
# Index 76 Topic: Training, Validation, and Testing of Machine Learning Models
# Index 77 Topic: Training, Validation, and Testing of Machine Learning Models
# Index 78 Topic: Training, Validation, and Testing of Machine Learning Models
# Index 79 Topic: Training, Validation, and Testing of Machine Learning Models
# Index 80 Topic: Training, Validation, and Testing of Machine Learning Models
# Index 81 Topic: Training, Validation, and Testing of Machine Learning Models
# Index 82 Topic: Training, Validation, and Testing of Machine Learning Models
# Index 83 Topic: Training, Validation, and Testing of Machine Learning Models
# Index 84 Topic: Training, Validation, and Testing of Machine Learning Models
# Index 85 Topic: Training, Validation, and Testing of Machine Learning Models
# Index 86 Topic: Training, Validation, and Testing of Machine Learning Models
# Index 87 Topic: Training, Validation, and Testing of Machine Learning Models
# Index 88 Topic: Training, Validation, and Testing of Machine Learning Models
# Index 89 Topic: Training, Validation, and Testing of Machine Learning Models
# Index 90 Topic: Training, Validation, and Testing of Machine Learning Models
# Index 91 Topic: Training, Validation, and Testing of Machine Learning Models
# Index 92 Topic: Training, Validation, and Testing of Machine Learning Models
# Index 93 Topic: Training, Validation, and Testing of Machine Learning Models
# Index 94 Topic: Training, Validation, and Testing of Machine Learning Models
# Index 95 Topic: Training, Validation, and Testing of Machine Learning Models
# Index 96 Topic: Training, Validation, and Testing of Machine Learning Models
# Index 97 Topic: Gradient Boosted Tree Models
# Index 98 Topic: Gradient Boosted Tree Models
# Index 99 Topic: Gradient Boosted Tree Models
# Index 100 Topic: Gradient Boosted Tree Models
# Index 101 Topic: Gradient Boosted Tree Models
# Index 102 Topic: Gradient Boosted Tree Models
# Index 103 Topic: Gradient Boosted Tree Models
# Index 104 Topic: Gradient Boosted Tree Models
# Index 105 Topic: Gradient Boosted Tree Models
# Index 106 Topic: Gradient Boosted Tree Models
# Index 107 Topic: Gradient Boosted Tree Models
# Index 108 Topic: Gradient Boosted Tree Models
# Index 109 Topic: Gradient Boosted Tree Models
# Index 110 Topic: Gradient Boosted Tree Models
# Index 111 Topic: Gradient Boosted Tree Models
# Index 112 Topic: Gradient Boosted Tree Models
# Index 113 Topic: Gradient Boosted Tree Models
# Index 114 Topic: Gradient Boosted Tree Models
# Index 115 Topic: Gradient Boosted Tree Models
# Index 116 Topic: Gradient Boosted Tree Models
# Index 117 Topic: Gradient Boosted Tree Models
# Index 118 Topic: Gradient Boosted Tree Models
# Index 119 Topic: Gradient Boosted Tree Models
# Index 120 Topic: Gradient Boosted Tree Models
# Index 121 Topic: Gradient Boosted Tree Models
# Index 122 Topic: Gradient Boosted Tree Models
# Index 123 Topic: Gradient Boosted Tree Models
# Index 124 Topic: Gradient Boosted Tree Models
# Index 125 Topic: Gradient Boosted Tree Models
# Index 126 Topic: Gradient Boosted Tree Models
# Index 127 Topic: Gradient Boosted Tree Models
# Index 128 Topic: Gradient Boosted Tree Models
# Index 129 Topic: Gradient Boosted Tree Models
# Index 130 Topic: Gradient Boosted Tree Models
# Index 131 Topic: Gradient Boosted Tree Models
# Index 132 Topic: Gradient Boosted Tree Models
# Index 133 Topic: Gradient Boosted Tree Models
# Index 134 Topic: Gradient Boosted Tree Models
# Index 135 Topic: Gradient Boosted Tree Models
# Index 136 Topic: Gradient Boosted Tree Models
# Index 137 Topic: Gradient Boosted Tree Models
# Index 138 Topic: Gradient Boosted Tree Models
# Index 139 Topic: Gradient Boosted Tree Models
# Index 140 Topic: Gradient Boosted Tree Models
# Index 141 Topic: Gradient Boosted Tree Models
# Index 142 Topic: Gradient Boosted Tree Models
# Index 143 Topic: Gradient Boosted Tree Models
# Index 144 Topic: Gradient Boosted Tree Models
# Index 145 Topic: Linear Regression, Logistic Regression, and Multilayer Perceptron
# Index 146 Topic: Linear Regression, Logistic Regression, and Multilayer Perceptron
# Index 147 Topic: Linear Regression, Logistic Regression, and Multilayer Perceptron
# Index 148 Topic: Linear Regression, Logistic Regression, and Multilayer Perceptron
# Index 149 Topic: Linear Regression, Logistic Regression, and Multilayer Perceptron
# Index 150 Topic: Linear Regression, Logistic Regression, and Multilayer Perceptron
# Index 151 Topic: Linear Regression, Logistic Regression, and Multilayer Perceptron
# Index 152 Topic: Linear Regression, Logistic Regression, and Multilayer Perceptron
# Index 153 Topic: Linear Regression, Logistic Regression, and Multilayer Perceptron
# Index 154 Topic: Linear Regression, Logistic Regression, and Multilayer Perceptron
# Index 155 Topic: Linear Regression, Logistic Regression, and Multilayer Perceptron
# Index 156 Topic: Linear Regression, Logistic Regression, and Multilayer Perceptron
# Index 157 Topic: Linear Regression, Logistic Regression, and Multilayer Perceptron
# Index 158 Topic: Linear Regression, Logistic Regression, and Multilayer Perceptron
# Index 159 Topic: Linear Regression, Logistic Regression, and Multilayer Perceptron
# Index 160 Topic: Linear Regression, Logistic Regression, and Multilayer Perceptron
# Index 161 Topic: Linear Regression, Logistic Regression, and Multilayer Perceptron
# Index 162 Topic: Linear Regression, Logistic Regression, and Multilayer Perceptron
# Index 163 Topic: Linear Regression, Logistic Regression, and Multilayer Perceptron
# Index 164 Topic: Linear Regression, Logistic Regression, and Multilayer Perceptron
# Index 165 Topic: Linear Regression, Logistic Regression, and Multilayer Perceptron
# Index 166 Topic: Linear Regression, Logistic Regression, and Multilayer Perceptron
# Index 167 Topic: Linear Regression, Logistic Regression, and Multilayer Perceptron
# Index 168 Topic: Linear Regression, Logistic Regression, and Multilayer Perceptron
# Index 169 Topic: Linear Regression, Logistic Regression, and Multilayer Perceptron
# Index 170 Topic: Linear Regression, Logistic Regression, and Multilayer Perceptron
# Index 171 Topic: Linear Regression, Logistic Regression, and Multilayer Perceptron
# Index 172 Topic: Linear Regression, Logistic Regression, and Multilayer Perceptron
# Index 173 Topic: Linear Regression, Logistic Regression, and Multilayer Perceptron
# Index 174 Topic: Linear Regression, Logistic Regression, and Multilayer Perceptron
# Index 175 Topic: Linear Regression, Logistic Regression, and Multilayer Perceptron
# Index 176 Topic: Linear Regression, Logistic Regression, and Multilayer Perceptron
# Index 177 Topic: Linear Regression, Logistic Regression, and Multilayer Perceptron
# Index 178 Topic: Linear Regression, Logistic Regression, and Multilayer Perceptron
# Index 179 Topic: Linear Regression, Logistic Regression, and Multilayer Perceptron
# Index 180 Topic: Linear Regression, Logistic Regression, and Multilayer Perceptron
# Index 181 Topic: Linear Regression, Logistic Regression, and Multilayer Perceptron
# Index 182 Topic: Linear Regression, Logistic Regression, and Multilayer Perceptron
# Index 183 Topic: Linear Regression, Logistic Regression, and Multilayer Perceptron
# Index 184 Topic: Linear Regression, Logistic Regression, and Multilayer Perceptron
# Index 185 Topic: Linear Regression, Logistic Regression, and Multilayer Perceptron
# Index 186 Topic: Linear Regression, Logistic Regression, and Multilayer Perceptron
# Index 187 Topic: Linear Regression, Logistic Regression, and Multilayer Perceptron
# Index 188 Topic: Linear Regression, Logistic Regression, and Multilayer Perceptron
# Index 189 Topic: Linear Regression, Logistic Regression, and Multilayer Perceptron
# Index 190 Topic: Linear Regression, Logistic Regression, and Multilayer Perceptron
# Index 191 Topic: Linear Regression, Logistic Regression, and Multilayer Perceptron
# Index 192 Topic: Linear Regression, Logistic Regression, and Multilayer Perceptron
# Index 193 Topic: Stochastic Gradient Descent
# Index 194 Topic: Stochastic Gradient Descent
# Index 195 Topic: Stochastic Gradient Descent
# Index 196 Topic: Stochastic Gradient Descent
# Index 197 Topic: Stochastic Gradient Descent
# Index 198 Topic: Stochastic Gradient Descent
# Index 199 Topic: Stochastic Gradient Descent
# Index 200 Topic: Stochastic Gradient Descent
# Index 201 Topic: Stochastic Gradient Descent
# Index 202 Topic: Stochastic Gradient Descent
# Index 203 Topic: Stochastic Gradient Descent
# Index 204 Topic: Stochastic Gradient Descent
# Index 205 Topic: Stochastic Gradient Descent
# Index 206 Topic: Stochastic Gradient Descent
# Index 207 Topic: Stochastic Gradient Descent
# Index 208 Topic: Stochastic Gradient Descent
# Index 209 Topic: Stochastic Gradient Descent
# Index 210 Topic: Stochastic Gradient Descent
# Index 211 Topic: Stochastic Gradient Descent
# Index 212 Topic: Stochastic Gradient Descent
# Index 213 Topic: Stochastic Gradient Descent
# Index 214 Topic: Stochastic Gradient Descent
# Index 215 Topic: Stochastic Gradient Descent
# Index 216 Topic: Stochastic Gradient Descent
# Index 217 Topic: Stochastic Gradient Descent
# Index 218 Topic: Stochastic Gradient Descent
# Index 219 Topic: Stochastic Gradient Descent
# Index 220 Topic: Stochastic Gradient Descent
# Index 221 Topic: Stochastic Gradient Descent
# Index 222 Topic: Stochastic Gradient Descent
# Index 223 Topic: Stochastic Gradient Descent
# Index 224 Topic: Stochastic Gradient Descent
# Index 225 Topic: Stochastic Gradient Descent
# Index 226 Topic: Stochastic Gradient Descent
# Index 227 Topic: Stochastic Gradient Descent
# Index 228 Topic: Stochastic Gradient Descent
# Index 229 Topic: Stochastic Gradient Descent
# Index 230 Topic: Stochastic Gradient Descent
# Index 231 Topic: Stochastic Gradient Descent
# Index 232 Topic: Stochastic Gradient Descent
# Index 233 Topic: Stochastic Gradient Descent
# Index 234 Topic: Stochastic Gradient Descent
# Index 235 Topic: Stochastic Gradient Descent
# Index 236 Topic: Stochastic Gradient Descent
# Index 237 Topic: Stochastic Gradient Descent
# Index 238 Topic: Stochastic Gradient Descent
# Index 239 Topic: Stochastic Gradient Descent
# Index 240 Topic: Stochastic Gradient Descent
# Index 241 Topic: Backpropagation
# Index 242 Topic: Backpropagation
# Index 243 Topic: Backpropagation
# Index 244 Topic: Backpropagation
# Index 245 Topic: Backpropagation
# Index 246 Topic: Backpropagation
# Index 247 Topic: Backpropagation
# Index 248 Topic: Backpropagation
# Index 249 Topic: Backpropagation
# Index 250 Topic: Backpropagation
# Index 251 Topic: Backpropagation
# Index 252 Topic: Backpropagation
# Index 253 Topic: Backpropagation
# Index 254 Topic: Backpropagation
# Index 255 Topic: Backpropagation
# Index 256 Topic: Backpropagation
# Index 257 Topic: Backpropagation
# Index 258 Topic: Backpropagation
# Index 259 Topic: Backpropagation
# Index 260 Topic: Backpropagation
# Index 261 Topic: Backpropagation
# Index 262 Topic: Backpropagation
# Index 263 Topic: Backpropagation
# Index 264 Topic: Backpropagation
# Index 265 Topic: Backpropagation
# Index 266 Topic: Backpropagation
# Index 267 Topic: Backpropagation
# Index 268 Topic: Backpropagation
# Index 269 Topic: Backpropagation
# Index 270 Topic: Backpropagation
# Index 271 Topic: Backpropagation
# Index 272 Topic: Backpropagation
# Index 273 Topic: Backpropagation
# Index 274 Topic: Backpropagation
# Index 275 Topic: Backpropagation
# Index 276 Topic: Backpropagation
# Index 277 Topic: Backpropagation
# Index 278 Topic: Backpropagation
# Index 279 Topic: Backpropagation
# Index 280 Topic: Backpropagation
# Index 281 Topic: Backpropagation
# Index 282 Topic: Backpropagation
# Index 283 Topic: Backpropagation
# Index 284 Topic: Backpropagation
# Index 285 Topic: Backpropagation
# Index 286 Topic: Backpropagation
# Index 287 Topic: Backpropagation
# Index 288 Topic: Backpropagation
# Index 289 Topic: Foundations of Computer Vision and Convolutional Neural Networks
# Index 290 Topic: Foundations of Computer Vision and Convolutional Neural Networks
# Index 291 Topic: Foundations of Computer Vision and Convolutional Neural Networks
# Index 292 Topic: Foundations of Computer Vision and Convolutional Neural Networks
# Index 293 Topic: Foundations of Computer Vision and Convolutional Neural Networks
# Index 294 Topic: Foundations of Computer Vision and Convolutional Neural Networks
# Index 295 Topic: Foundations of Computer Vision and Convolutional Neural Networks
# Index 296 Topic: Foundations of Computer Vision and Convolutional Neural Networks
# Index 297 Topic: Foundations of Computer Vision and Convolutional Neural Networks
# Index 298 Topic: Foundations of Computer Vision and Convolutional Neural Networks
# Index 299 Topic: Foundations of Computer Vision and Convolutional Neural Networks
# Index 300 Topic: Foundations of Computer Vision and Convolutional Neural Networks
# Index 301 Topic: Foundations of Computer Vision and Convolutional Neural Networks
# Index 302 Topic: Foundations of Computer Vision and Convolutional Neural Networks
# Index 303 Topic: Foundations of Computer Vision and Convolutional Neural Networks
# Index 304 Topic: Foundations of Computer Vision and Convolutional Neural Networks
# Index 305 Topic: Foundations of Computer Vision and Convolutional Neural Networks
# Index 306 Topic: Foundations of Computer Vision and Convolutional Neural Networks
# Index 307 Topic: Foundations of Computer Vision and Convolutional Neural Networks
# Index 308 Topic: Foundations of Computer Vision and Convolutional Neural Networks
# Index 309 Topic: Foundations of Computer Vision and Convolutional Neural Networks
# Index 310 Topic: Foundations of Computer Vision and Convolutional Neural Networks
# Index 311 Topic: Foundations of Computer Vision and Convolutional Neural Networks
# Index 312 Topic: Foundations of Computer Vision and Convolutional Neural Networks
# Index 313 Topic: Foundations of Computer Vision and Convolutional Neural Networks
# Index 314 Topic: Foundations of Computer Vision and Convolutional Neural Networks
# Index 315 Topic: Foundations of Computer Vision and Convolutional Neural Networks
# Index 316 Topic: Foundations of Computer Vision and Convolutional Neural Networks
# Index 317 Topic: Foundations of Computer Vision and Convolutional Neural Networks
# Index 318 Topic: Foundations of Computer Vision and Convolutional Neural Networks
# Index 319 Topic: Foundations of Computer Vision and Convolutional Neural Networks
# Index 320 Topic: Foundations of Computer Vision and Convolutional Neural Networks
# Index 321 Topic: Foundations of Computer Vision and Convolutional Neural Networks
# Index 322 Topic: Foundations of Computer Vision and Convolutional Neural Networks
# Index 323 Topic: Foundations of Computer Vision and Convolutional Neural Networks
# Index 324 Topic: Foundations of Computer Vision and Convolutional Neural Networks
# Index 325 Topic: Foundations of Computer Vision and Convolutional Neural Networks
# Index 326 Topic: Foundations of Computer Vision and Convolutional Neural Networks
# Index 327 Topic: Foundations of Computer Vision and Convolutional Neural Networks
# Index 328 Topic: Foundations of Computer Vision and Convolutional Neural Networks
# Index 329 Topic: Foundations of Computer Vision and Convolutional Neural Networks
# Index 330 Topic: Foundations of Computer Vision and Convolutional Neural Networks
# Index 331 Topic: Foundations of Computer Vision and Convolutional Neural Networks
# Index 332 Topic: Foundations of Computer Vision and Convolutional Neural Networks
# Index 333 Topic: Foundations of Computer Vision and Convolutional Neural Networks
# Index 334 Topic: Foundations of Computer Vision and Convolutional Neural Networks
# Index 335 Topic: Foundations of Computer Vision and Convolutional Neural Networks
# Index 336 Topic: Foundations of Computer Vision and Convolutional Neural Networks
# Index 337 Topic: Transfer Learning for Computer Vision
# Index 338 Topic: Transfer Learning for Computer Vision
# Index 339 Topic: Transfer Learning for Computer Vision
# Index 340 Topic: Transfer Learning for Computer Vision
# Index 341 Topic: Transfer Learning for Computer Vision
# Index 342 Topic: Transfer Learning for Computer Vision
# Index 343 Topic: Transfer Learning for Computer Vision
# Index 344 Topic: Transfer Learning for Computer Vision
# Index 345 Topic: Transfer Learning for Computer Vision
# Index 346 Topic: Transfer Learning for Computer Vision
# Index 347 Topic: Transfer Learning for Computer Vision
# Index 348 Topic: Transfer Learning for Computer Vision
# Index 349 Topic: Transfer Learning for Computer Vision
# Index 350 Topic: Transfer Learning for Computer Vision
# Index 351 Topic: Transfer Learning for Computer Vision
# Index 352 Topic: Transfer Learning for Computer Vision
# Index 353 Topic: Transfer Learning for Computer Vision
# Index 354 Topic: Transfer Learning for Computer Vision
# Index 355 Topic: Transfer Learning for Computer Vision
# Index 356 Topic: Transfer Learning for Computer Vision
# Index 357 Topic: Transfer Learning for Computer Vision
# Index 358 Topic: Transfer Learning for Computer Vision
# Index 359 Topic: Transfer Learning for Computer Vision
# Index 360 Topic: Transfer Learning for Computer Vision
# Index 361 Topic: Transfer Learning for Computer Vision
# Index 362 Topic: Transfer Learning for Computer Vision
# Index 363 Topic: Transfer Learning for Computer Vision
# Index 364 Topic: Transfer Learning for Computer Vision
# Index 365 Topic: Transfer Learning for Computer Vision
# Index 366 Topic: Transfer Learning for Computer Vision
# Index 367 Topic: Transfer Learning for Computer Vision
# Index 368 Topic: Transfer Learning for Computer Vision
# Index 369 Topic: Transfer Learning for Computer Vision
# Index 370 Topic: Transfer Learning for Computer Vision
# Index 371 Topic: Transfer Learning for Computer Vision
# Index 372 Topic: Transfer Learning for Computer Vision
# Index 373 Topic: Transfer Learning for Computer Vision
# Index 374 Topic: Transfer Learning for Computer Vision
# Index 375 Topic: Transfer Learning for Computer Vision
# Index 376 Topic: Transfer Learning for Computer Vision
# Index 377 Topic: Transfer Learning for Computer Vision
# Index 378 Topic: Transfer Learning for Computer Vision
# Index 379 Topic: Transfer Learning for Computer Vision
# Index 380 Topic: Transfer Learning for Computer Vision
# Index 381 Topic: Transfer Learning for Computer Vision
# Index 382 Topic: Transfer Learning for Computer Vision
# Index 383 Topic: Transfer Learning for Computer Vision
# Index 384 Topic: Transfer Learning for Computer Vision
# Index 385 Topic: Image Segmentation and Object Detection
# Index 386 Topic: Image Segmentation and Object Detection
# Index 387 Topic: Image Segmentation and Object Detection
# Index 388 Topic: Image Segmentation and Object Detection
# Index 389 Topic: Image Segmentation and Object Detection
# Index 390 Topic: Image Segmentation and Object Detection
# Index 391 Topic: Image Segmentation and Object Detection
# Index 392 Topic: Image Segmentation and Object Detection
# Index 393 Topic: Image Segmentation and Object Detection
# Index 394 Topic: Image Segmentation and Object Detection
# Index 395 Topic: Image Segmentation and Object Detection
# Index 396 Topic: Image Segmentation and Object Detection
# Index 397 Topic: Image Segmentation and Object Detection
# Index 398 Topic: Image Segmentation and Object Detection
# Index 399 Topic: Image Segmentation and Object Detection
# Index 400 Topic: Image Segmentation and Object Detection
# Index 401 Topic: Image Segmentation and Object Detection
# Index 402 Topic: Image Segmentation and Object Detection
# Index 403 Topic: Image Segmentation and Object Detection
# Index 404 Topic: Image Segmentation and Object Detection
# Index 405 Topic: Image Segmentation and Object Detection
# Index 406 Topic: Image Segmentation and Object Detection
# Index 407 Topic: Image Segmentation and Object Detection
# Index 408 Topic: Image Segmentation and Object Detection
# Index 409 Topic: Image Segmentation and Object Detection
# Index 410 Topic: Image Segmentation and Object Detection
# Index 411 Topic: Image Segmentation and Object Detection
# Index 412 Topic: Image Segmentation and Object Detection
# Index 413 Topic: Image Segmentation and Object Detection
# Index 414 Topic: Image Segmentation and Object Detection
# Index 415 Topic: Image Segmentation and Object Detection
# Index 416 Topic: Image Segmentation and Object Detection
# Index 417 Topic: Image Segmentation and Object Detection
# Index 418 Topic: Image Segmentation and Object Detection
# Index 419 Topic: Image Segmentation and Object Detection
# Index 420 Topic: Image Segmentation and Object Detection
# Index 421 Topic: Image Segmentation and Object Detection
# Index 422 Topic: Image Segmentation and Object Detection
# Index 423 Topic: Image Segmentation and Object Detection
# Index 424 Topic: Image Segmentation and Object Detection
# Index 425 Topic: Image Segmentation and Object Detection
# Index 426 Topic: Image Segmentation and Object Detection
# Index 427 Topic: Image Segmentation and Object Detection
# Index 428 Topic: Image Segmentation and Object Detection
# Index 429 Topic: Image Segmentation and Object Detection
# Index 430 Topic: Image Segmentation and Object Detection
# Index 431 Topic: Image Segmentation and Object Detection
# Index 432 Topic: Image Segmentation and Object Detection
# Index 433 Topic: Data Pre-processing for Natural Language Processing Tasks
# Index 434 Topic: Data Pre-processing for Natural Language Processing Tasks
# Index 435 Topic: Data Pre-processing for Natural Language Processing Tasks
# Index 436 Topic: Data Pre-processing for Natural Language Processing Tasks
# Index 437 Topic: Data Pre-processing for Natural Language Processing Tasks
# Index 438 Topic: Data Pre-processing for Natural Language Processing Tasks
# Index 439 Topic: Data Pre-processing for Natural Language Processing Tasks
# Index 440 Topic: Data Pre-processing for Natural Language Processing Tasks
# Index 441 Topic: Data Pre-processing for Natural Language Processing Tasks
# Index 442 Topic: Data Pre-processing for Natural Language Processing Tasks
# Index 443 Topic: Data Pre-processing for Natural Language Processing Tasks
# Index 444 Topic: Data Pre-processing for Natural Language Processing Tasks
# Index 445 Topic: Data Pre-processing for Natural Language Processing Tasks
# Index 446 Topic: Data Pre-processing for Natural Language Processing Tasks
# Index 447 Topic: Data Pre-processing for Natural Language Processing Tasks
# Index 448 Topic: Data Pre-processing for Natural Language Processing Tasks
# Index 449 Topic: Data Pre-processing for Natural Language Processing Tasks
# Index 450 Topic: Data Pre-processing for Natural Language Processing Tasks
# Index 451 Topic: Data Pre-processing for Natural Language Processing Tasks
# Index 452 Topic: Data Pre-processing for Natural Language Processing Tasks
# Index 453 Topic: Data Pre-processing for Natural Language Processing Tasks
# Index 454 Topic: Data Pre-processing for Natural Language Processing Tasks
# Index 455 Topic: Data Pre-processing for Natural Language Processing Tasks
# Index 456 Topic: Data Pre-processing for Natural Language Processing Tasks
# Index 457 Topic: Data Pre-processing for Natural Language Processing Tasks
# Index 458 Topic: Data Pre-processing for Natural Language Processing Tasks
# Index 459 Topic: Data Pre-processing for Natural Language Processing Tasks
# Index 460 Topic: Data Pre-processing for Natural Language Processing Tasks
# Index 461 Topic: Data Pre-processing for Natural Language Processing Tasks
# Index 462 Topic: Data Pre-processing for Natural Language Processing Tasks
# Index 463 Topic: Data Pre-processing for Natural Language Processing Tasks
# Index 464 Topic: Data Pre-processing for Natural Language Processing Tasks
# Index 465 Topic: Data Pre-processing for Natural Language Processing Tasks
# Index 466 Topic: Data Pre-processing for Natural Language Processing Tasks
# Index 467 Topic: Data Pre-processing for Natural Language Processing Tasks
# Index 468 Topic: Data Pre-processing for Natural Language Processing Tasks
# Index 469 Topic: Data Pre-processing for Natural Language Processing Tasks
# Index 470 Topic: Data Pre-processing for Natural Language Processing Tasks
# Index 471 Topic: Data Pre-processing for Natural Language Processing Tasks
# Index 472 Topic: Data Pre-processing for Natural Language Processing Tasks
# Index 473 Topic: Data Pre-processing for Natural Language Processing Tasks
# Index 474 Topic: Data Pre-processing for Natural Language Processing Tasks
# Index 475 Topic: Data Pre-processing for Natural Language Processing Tasks
# Index 476 Topic: Data Pre-processing for Natural Language Processing Tasks
# Index 477 Topic: Data Pre-processing for Natural Language Processing Tasks
# Index 478 Topic: Data Pre-processing for Natural Language Processing Tasks
# Index 479 Topic: Data Pre-processing for Natural Language Processing Tasks
# Index 480 Topic: Data Pre-processing for Natural Language Processing Tasks
# Index 481 Topic: Bag of Words Approach and Word Embedding
# Index 482 Topic: Bag of Words Approach and Word Embedding
# Index 483 Topic: Bag of Words Approach and Word Embedding
# Index 484 Topic: Bag of Words Approach and Word Embedding
# Index 485 Topic: Bag of Words Approach and Word Embedding
# Index 486 Topic: Bag of Words Approach and Word Embedding
# Index 487 Topic: Bag of Words Approach and Word Embedding
# Index 488 Topic: Bag of Words Approach and Word Embedding
# Index 489 Topic: Bag of Words Approach and Word Embedding
# Index 490 Topic: Bag of Words Approach and Word Embedding
# Index 491 Topic: Bag of Words Approach and Word Embedding
# Index 492 Topic: Bag of Words Approach and Word Embedding
# Index 493 Topic: Bag of Words Approach and Word Embedding
# Index 494 Topic: Bag of Words Approach and Word Embedding
# Index 495 Topic: Bag of Words Approach and Word Embedding
# Index 496 Topic: Bag of Words Approach and Word Embedding
# Index 497 Topic: Bag of Words Approach and Word Embedding
# Index 498 Topic: Bag of Words Approach and Word Embedding
# Index 499 Topic: Bag of Words Approach and Word Embedding
# Index 500 Topic: Bag of Words Approach and Word Embedding
# Index 501 Topic: Bag of Words Approach and Word Embedding
# Index 502 Topic: Bag of Words Approach and Word Embedding
# Index 503 Topic: Bag of Words Approach and Word Embedding
# Index 504 Topic: Bag of Words Approach and Word Embedding
# Index 505 Topic: Bag of Words Approach and Word Embedding
# Index 506 Topic: Bag of Words Approach and Word Embedding
# Index 507 Topic: Bag of Words Approach and Word Embedding
# Index 508 Topic: Bag of Words Approach and Word Embedding
# Index 509 Topic: Bag of Words Approach and Word Embedding
# Index 510 Topic: Bag of Words Approach and Word Embedding
# Index 511 Topic: Bag of Words Approach and Word Embedding
# Index 512 Topic: Bag of Words Approach and Word Embedding
# Index 513 Topic: Bag of Words Approach and Word Embedding
# Index 514 Topic: Bag of Words Approach and Word Embedding
# Index 515 Topic: Bag of Words Approach and Word Embedding
# Index 516 Topic: Bag of Words Approach and Word Embedding
# Index 517 Topic: Bag of Words Approach and Word Embedding
# Index 518 Topic: Bag of Words Approach and Word Embedding
# Index 519 Topic: Bag of Words Approach and Word Embedding
# Index 520 Topic: Bag of Words Approach and Word Embedding
# Index 521 Topic: Bag of Words Approach and Word Embedding
# Index 522 Topic: Bag of Words Approach and Word Embedding
# Index 523 Topic: Bag of Words Approach and Word Embedding
# Index 524 Topic: Bag of Words Approach and Word Embedding
# Index 525 Topic: Bag of Words Approach and Word Embedding
# Index 526 Topic: Bag of Words Approach and Word Embedding
# Index 527 Topic: Bag of Words Approach and Word Embedding
# Index 528 Topic: Bag of Words Approach and Word Embedding
# Index 529 Topic: Attention Mechanism in Transformers
# Index 530 Topic: Attention Mechanism in Transformers
# Index 531 Topic: Attention Mechanism in Transformers
# Index 532 Topic: Attention Mechanism in Transformers
# Index 533 Topic: Attention Mechanism in Transformers
# Index 534 Topic: Attention Mechanism in Transformers
# Index 535 Topic: Attention Mechanism in Transformers
# Index 536 Topic: Attention Mechanism in Transformers
# Index 537 Topic: Attention Mechanism in Transformers
# Index 538 Topic: Attention Mechanism in Transformers
# Index 539 Topic: Attention Mechanism in Transformers
# Index 540 Topic: Attention Mechanism in Transformers
# Index 541 Topic: Attention Mechanism in Transformers
# Index 542 Topic: Attention Mechanism in Transformers
# Index 543 Topic: Attention Mechanism in Transformers
# Index 544 Topic: Attention Mechanism in Transformers
# Index 545 Topic: Attention Mechanism in Transformers
# Index 546 Topic: Attention Mechanism in Transformers
# Index 547 Topic: Attention Mechanism in Transformers
# Index 548 Topic: Attention Mechanism in Transformers
# Index 549 Topic: Attention Mechanism in Transformers
# Index 550 Topic: Attention Mechanism in Transformers
# Index 551 Topic: Attention Mechanism in Transformers
# Index 552 Topic: Attention Mechanism in Transformers
# Index 553 Topic: Attention Mechanism in Transformers
# Index 554 Topic: Attention Mechanism in Transformers
# Index 555 Topic: Attention Mechanism in Transformers
# Index 556 Topic: Attention Mechanism in Transformers
# Index 557 Topic: Attention Mechanism in Transformers
# Index 558 Topic: Attention Mechanism in Transformers
# Index 559 Topic: Attention Mechanism in Transformers
# Index 560 Topic: Attention Mechanism in Transformers
# Index 561 Topic: Attention Mechanism in Transformers
# Index 562 Topic: Attention Mechanism in Transformers
# Index 563 Topic: Attention Mechanism in Transformers
# Index 564 Topic: Attention Mechanism in Transformers
# Index 565 Topic: Attention Mechanism in Transformers
# Index 566 Topic: Attention Mechanism in Transformers
# Index 567 Topic: Attention Mechanism in Transformers
# Index 568 Topic: Attention Mechanism in Transformers
# Index 569 Topic: Attention Mechanism in Transformers
# Index 570 Topic: Attention Mechanism in Transformers
# Index 571 Topic: Attention Mechanism in Transformers
# Index 572 Topic: Attention Mechanism in Transformers
# Index 573 Topic: Attention Mechanism in Transformers
# Index 574 Topic: Attention Mechanism in Transformers
# Index 575 Topic: Attention Mechanism in Transformers
# Index 576 Topic: Attention Mechanism in Transformers
# Index 577 Topic: Neural Machine Translation using Transformers
# Index 578 Topic: Neural Machine Translation using Transformers
# Index 579 Topic: Neural Machine Translation using Transformers
# Index 580 Topic: Neural Machine Translation using Transformers
# Index 581 Topic: Neural Machine Translation using Transformers
# Index 582 Topic: Neural Machine Translation using Transformers
# Index 583 Topic: Neural Machine Translation using Transformers
# Index 584 Topic: Neural Machine Translation using Transformers
# Index 585 Topic: Neural Machine Translation using Transformers
# Index 586 Topic: Neural Machine Translation using Transformers
# Index 587 Topic: Neural Machine Translation using Transformers
# Index 588 Topic: Neural Machine Translation using Transformers
# Index 589 Topic: Neural Machine Translation using Transformers
# Index 590 Topic: Neural Machine Translation using Transformers
# Index 591 Topic: Neural Machine Translation using Transformers
# Index 592 Topic: Neural Machine Translation using Transformers
# Index 593 Topic: Neural Machine Translation using Transformers
# Index 594 Topic: Neural Machine Translation using Transformers
# Index 595 Topic: Neural Machine Translation using Transformers
# Index 596 Topic: Neural Machine Translation using Transformers
# Index 597 Topic: Neural Machine Translation using Transformers
# Index 598 Topic: Neural Machine Translation using Transformers
# Index 599 Topic: Neural Machine Translation using Transformers
# Index 600 Topic: Neural Machine Translation using Transformers
# Index 601 Topic: Neural Machine Translation using Transformers
# Index 602 Topic: Neural Machine Translation using Transformers
# Index 603 Topic: Neural Machine Translation using Transformers
# Index 604 Topic: Neural Machine Translation using Transformers
# Index 605 Topic: Neural Machine Translation using Transformers
# Index 606 Topic: Neural Machine Translation using Transformers
# Index 607 Topic: Neural Machine Translation using Transformers
# Index 608 Topic: Neural Machine Translation using Transformers
# Index 609 Topic: Neural Machine Translation using Transformers
# Index 610 Topic: Neural Machine Translation using Transformers
# Index 611 Topic: Neural Machine Translation using Transformers
# Index 612 Topic: Neural Machine Translation using Transformers
# Index 613 Topic: Neural Machine Translation using Transformers
# Index 614 Topic: Neural Machine Translation using Transformers
# Index 615 Topic: Neural Machine Translation using Transformers
# Index 616 Topic: Neural Machine Translation using Transformers
# Index 617 Topic: Neural Machine Translation using Transformers
# Index 618 Topic: Neural Machine Translation using Transformers
# Index 619 Topic: Neural Machine Translation using Transformers
# Index 620 Topic: Neural Machine Translation using Transformers
# Index 621 Topic: Neural Machine Translation using Transformers
# Index 622 Topic: Neural Machine Translation using Transformers
# Index 623 Topic: Neural Machine Translation using Transformers
# Index 624 Topic: Neural Machine Translation using Transformers
# Index 625 Topic: Encoder, Decoder, and Sequence-to-Sequence Transformers
# Index 626 Topic: Encoder, Decoder, and Sequence-to-Sequence Transformers
# Index 627 Topic: Encoder, Decoder, and Sequence-to-Sequence Transformers
# Index 628 Topic: Encoder, Decoder, and Sequence-to-Sequence Transformers
# Index 629 Topic: Encoder, Decoder, and Sequence-to-Sequence Transformers
# Index 630 Topic: Encoder, Decoder, and Sequence-to-Sequence Transformers
# Index 631 Topic: Encoder, Decoder, and Sequence-to-Sequence Transformers
# Index 632 Topic: Encoder, Decoder, and Sequence-to-Sequence Transformers
# Index 633 Topic: Encoder, Decoder, and Sequence-to-Sequence Transformers
# Index 634 Topic: Encoder, Decoder, and Sequence-to-Sequence Transformers
# Index 635 Topic: Encoder, Decoder, and Sequence-to-Sequence Transformers
# Index 636 Topic: Encoder, Decoder, and Sequence-to-Sequence Transformers
# Index 637 Topic: Encoder, Decoder, and Sequence-to-Sequence Transformers
# Index 638 Topic: Encoder, Decoder, and Sequence-to-Sequence Transformers
# Index 639 Topic: Encoder, Decoder, and Sequence-to-Sequence Transformers
# Index 640 Topic: Encoder, Decoder, and Sequence-to-Sequence Transformers
# Index 641 Topic: Encoder, Decoder, and Sequence-to-Sequence Transformers
# Index 642 Topic: Encoder, Decoder, and Sequence-to-Sequence Transformers
# Index 643 Topic: Encoder, Decoder, and Sequence-to-Sequence Transformers
# Index 644 Topic: Encoder, Decoder, and Sequence-to-Sequence Transformers
# Index 645 Topic: Encoder, Decoder, and Sequence-to-Sequence Transformers
# Index 646 Topic: Encoder, Decoder, and Sequence-to-Sequence Transformers
# Index 647 Topic: Encoder, Decoder, and Sequence-to-Sequence Transformers
# Index 648 Topic: Encoder, Decoder, and Sequence-to-Sequence Transformers
# Index 649 Topic: Encoder, Decoder, and Sequence-to-Sequence Transformers
# Index 650 Topic: Encoder, Decoder, and Sequence-to-Sequence Transformers
# Index 651 Topic: Encoder, Decoder, and Sequence-to-Sequence Transformers
# Index 652 Topic: Encoder, Decoder, and Sequence-to-Sequence Transformers
# Index 653 Topic: Encoder, Decoder, and Sequence-to-Sequence Transformers
# Index 654 Topic: Encoder, Decoder, and Sequence-to-Sequence Transformers
# Index 655 Topic: Encoder, Decoder, and Sequence-to-Sequence Transformers
# Index 656 Topic: Encoder, Decoder, and Sequence-to-Sequence Transformers
# Index 657 Topic: Encoder, Decoder, and Sequence-to-Sequence Transformers
# Index 658 Topic: Encoder, Decoder, and Sequence-to-Sequence Transformers
# Index 659 Topic: Encoder, Decoder, and Sequence-to-Sequence Transformers
# Index 660 Topic: Encoder, Decoder, and Sequence-to-Sequence Transformers
# Index 661 Topic: Encoder, Decoder, and Sequence-to-Sequence Transformers
# Index 662 Topic: Encoder, Decoder, and Sequence-to-Sequence Transformers
# Index 663 Topic: Encoder, Decoder, and Sequence-to-Sequence Transformers
# Index 664 Topic: Encoder, Decoder, and Sequence-to-Sequence Transformers
# Index 665 Topic: Encoder, Decoder, and Sequence-to-Sequence Transformers
# Index 666 Topic: Encoder, Decoder, and Sequence-to-Sequence Transformers
# Index 667 Topic: Encoder, Decoder, and Sequence-to-Sequence Transformers
# Index 668 Topic: Encoder, Decoder, and Sequence-to-Sequence Transformers
# Index 669 Topic: Encoder, Decoder, and Sequence-to-Sequence Transformers
# Index 670 Topic: Encoder, Decoder, and Sequence-to-Sequence Transformers
# Index 671 Topic: Encoder, Decoder, and Sequence-to-Sequence Transformers
# Index 672 Topic: Encoder, Decoder, and Sequence-to-Sequence Transformers
# Index 673 Topic: Pretraining, Finetuning, and Reinforcement Learning with Human Feedback
# Index 674 Topic: Pretraining, Finetuning, and Reinforcement Learning with Human Feedback
# Index 675 Topic: Pretraining, Finetuning, and Reinforcement Learning with Human Feedback
# Index 676 Topic: Pretraining, Finetuning, and Reinforcement Learning with Human Feedback
# Index 677 Topic: Pretraining, Finetuning, and Reinforcement Learning with Human Feedback
# Index 678 Topic: Pretraining, Finetuning, and Reinforcement Learning with Human Feedback
# Index 679 Topic: Pretraining, Finetuning, and Reinforcement Learning with Human Feedback
# Index 680 Topic: Pretraining, Finetuning, and Reinforcement Learning with Human Feedback
# Index 681 Topic: Pretraining, Finetuning, and Reinforcement Learning with Human Feedback
# Index 682 Topic: Pretraining, Finetuning, and Reinforcement Learning with Human Feedback
# Index 683 Topic: Pretraining, Finetuning, and Reinforcement Learning with Human Feedback
# Index 684 Topic: Pretraining, Finetuning, and Reinforcement Learning with Human Feedback
# Index 685 Topic: Pretraining, Finetuning, and Reinforcement Learning with Human Feedback
# Index 686 Topic: Pretraining, Finetuning, and Reinforcement Learning with Human Feedback
# Index 687 Topic: Pretraining, Finetuning, and Reinforcement Learning with Human Feedback
# Index 688 Topic: Pretraining, Finetuning, and Reinforcement Learning with Human Feedback
# Index 689 Topic: Pretraining, Finetuning, and Reinforcement Learning with Human Feedback
# Index 690 Topic: Pretraining, Finetuning, and Reinforcement Learning with Human Feedback
# Index 691 Topic: Pretraining, Finetuning, and Reinforcement Learning with Human Feedback
# Index 692 Topic: Pretraining, Finetuning, and Reinforcement Learning with Human Feedback
# Index 693 Topic: Pretraining, Finetuning, and Reinforcement Learning with Human Feedback
# Index 694 Topic: Pretraining, Finetuning, and Reinforcement Learning with Human Feedback
# Index 695 Topic: Pretraining, Finetuning, and Reinforcement Learning with Human Feedback
# Index 696 Topic: Pretraining, Finetuning, and Reinforcement Learning with Human Feedback
# Index 697 Topic: Pretraining, Finetuning, and Reinforcement Learning with Human Feedback
# Index 698 Topic: Pretraining, Finetuning, and Reinforcement Learning with Human Feedback
# Index 699 Topic: Pretraining, Finetuning, and Reinforcement Learning with Human Feedback
# Index 700 Topic: Pretraining, Finetuning, and Reinforcement Learning with Human Feedback
# Index 701 Topic: Pretraining, Finetuning, and Reinforcement Learning with Human Feedback
# Index 702 Topic: Pretraining, Finetuning, and Reinforcement Learning with Human Feedback
# Index 703 Topic: Pretraining, Finetuning, and Reinforcement Learning with Human Feedback
# Index 704 Topic: Pretraining, Finetuning, and Reinforcement Learning with Human Feedback
# Index 705 Topic: Pretraining, Finetuning, and Reinforcement Learning with Human Feedback
# Index 706 Topic: Pretraining, Finetuning, and Reinforcement Learning with Human Feedback
# Index 707 Topic: Pretraining, Finetuning, and Reinforcement Learning with Human Feedback
# Index 708 Topic: Pretraining, Finetuning, and Reinforcement Learning with Human Feedback
# Index 709 Topic: Pretraining, Finetuning, and Reinforcement Learning with Human Feedback
# Index 710 Topic: Pretraining, Finetuning, and Reinforcement Learning with Human Feedback
# Index 711 Topic: Pretraining, Finetuning, and Reinforcement Learning with Human Feedback
# Index 712 Topic: Pretraining, Finetuning, and Reinforcement Learning with Human Feedback
# Index 713 Topic: Pretraining, Finetuning, and Reinforcement Learning with Human Feedback
# Index 714 Topic: Pretraining, Finetuning, and Reinforcement Learning with Human Feedback
#
# Sheet: PS2
# Index 1 Topic: Decision Tree Models
# Index 2 Topic: Decision Tree Models
# Index 3 Topic: Decision Tree Models
# Index 4 Topic: Decision Tree Models
# Index 5 Topic: Decision Tree Models
# Index 6 Topic: Decision Tree Models
# Index 7 Topic: Decision Tree Models
# Index 8 Topic: Decision Tree Models
# Index 9 Topic: Decision Tree Models
# Index 10 Topic: Decision Tree Models
# Index 11 Topic: Decision Tree Models
# Index 12 Topic: Decision Tree Models
# Index 13 Topic: Decision Tree Models
# Index 14 Topic: Decision Tree Models
# Index 15 Topic: Decision Tree Models
# Index 16 Topic: Decision Tree Models
# Index 17 Topic: Decision Tree Models
# Index 18 Topic: Decision Tree Models
# Index 19 Topic: Decision Tree Models
# Index 20 Topic: Decision Tree Models
# Index 21 Topic: Decision Tree Models
# Index 22 Topic: Decision Tree Models
# Index 23 Topic: Decision Tree Models
# Index 24 Topic: Decision Tree Models
# Index 25 Topic: Decision Tree Models
# Index 26 Topic: Decision Tree Models
# Index 27 Topic: Decision Tree Models
# Index 28 Topic: Decision Tree Models
# Index 29 Topic: Decision Tree Models
# Index 30 Topic: Decision Tree Models
# Index 31 Topic: Decision Tree Models
# Index 32 Topic: Decision Tree Models
# Index 33 Topic: Decision Tree Models
# Index 34 Topic: Decision Tree Models
# Index 35 Topic: Decision Tree Models
# Index 36 Topic: Decision Tree Models
# Index 37 Topic: Decision Tree Models
# Index 38 Topic: Decision Tree Models
# Index 39 Topic: Decision Tree Models
# Index 40 Topic: Decision Tree Models
# Index 41 Topic: Decision Tree Models
# Index 42 Topic: Decision Tree Models
# Index 43 Topic: Decision Tree Models
# Index 44 Topic: Decision Tree Models
# Index 45 Topic: Decision Tree Models
# Index 46 Topic: Decision Tree Models
# Index 47 Topic: Decision Tree Models
# Index 48 Topic: Decision Tree Models
# Index 49 Topic: Training, Validation, and Testing of Machine Learning Models
# Index 50 Topic: Training, Validation, and Testing of Machine Learning Models
# Index 51 Topic: Training, Validation, and Testing of Machine Learning Models
# Index 52 Topic: Training, Validation, and Testing of Machine Learning Models
# Index 53 Topic: Training, Validation, and Testing of Machine Learning Models
# Index 54 Topic: Training, Validation, and Testing of Machine Learning Models
# Index 55 Topic: Training, Validation, and Testing of Machine Learning Models
# Index 56 Topic: Training, Validation, and Testing of Machine Learning Models
# Index 57 Topic: Training, Validation, and Testing of Machine Learning Models
# Index 58 Topic: Training, Validation, and Testing of Machine Learning Models
# Index 59 Topic: Training, Validation, and Testing of Machine Learning Models
# Index 60 Topic: Training, Validation, and Testing of Machine Learning Models
# Index 61 Topic: Training, Validation, and Testing of Machine Learning Models
# Index 62 Topic: Training, Validation, and Testing of Machine Learning Models
# Index 63 Topic: Training, Validation, and Testing of Machine Learning Models
# Index 64 Topic: Training, Validation, and Testing of Machine Learning Models
# Index 65 Topic: Training, Validation, and Testing of Machine Learning Models
# Index 66 Topic: Training, Validation, and Testing of Machine Learning Models
# Index 67 Topic: Training, Validation, and Testing of Machine Learning Models
# Index 68 Topic: Training, Validation, and Testing of Machine Learning Models
# Index 69 Topic: Training, Validation, and Testing of Machine Learning Models
# Index 70 Topic: Training, Validation, and Testing of Machine Learning Models
# Index 71 Topic: Training, Validation, and Testing of Machine Learning Models
# Index 72 Topic: Training, Validation, and Testing of Machine Learning Models
# Index 73 Topic: Training, Validation, and Testing of Machine Learning Models
# Index 74 Topic: Training, Validation, and Testing of Machine Learning Models
# Index 75 Topic: Training, Validation, and Testing of Machine Learning Models
# Index 76 Topic: Training, Validation, and Testing of Machine Learning Models
# Index 77 Topic: Training, Validation, and Testing of Machine Learning Models
# Index 78 Topic: Training, Validation, and Testing of Machine Learning Models
# ...
# Index 223 Topic: Stochastic Gradient Descent
# Index 224 Topic: Stochastic Gradient Descent
# Index 225 Topic: Stochastic Gradient Descent
# Index 226 Topic: Stochastic Gradient Descent
# Index 227 Topic: Stochastic Gradient Descent
# Index 228 Topic: Stochastic Gradient Descent
# Index 229 Topic: Stochastic Gradient Descent
# Index 230 Topic: Stochastic Gradient Descent
# Index 231 Topic: Stochastic Gradient Descent
# Index 232 Topic: Stochastic Gradient Descent
# Index 233 Topic: Stochastic Gradient Descent
# Index 234 Topic: Stochastic Gradient Descent
# Index 235 Topic: Stochastic Gradient Descent
# Index 236 Topic: Stochastic Gradient Descent
# Index 237 Topic: Stochastic Gradient Descent
# Index 238 Topic: Stochastic Gradient Descent
# Index 239 Topic: Stochastic Gradient Descent
# Index 240 Topic: Stochastic Gradient Descent
# Index 241 Topic: Backpropagation
# Index 242 Topic: Backpropagation
# Index 243 Topic: Backpropagation
# Index 244 Topic: Backpropagation
# Index 245 Topic: Backpropagation
# Index 246 Topic: Backpropagation
# Index 247 Topic: Backpropagation
# Index 248 Topic: Backpropagation
# Index 249 Topic: Backpropagation
# Index 250 Topic: Backpropagation
# Index 251 Topic: Backpropagation
# Index 252 Topic: Backpropagation
# Index 253 Topic: Backpropagation
# Index 254 Topic: Backpropagation
# Index 255 Topic: Backpropagation
# Index 256 Topic: Backpropagation
# Index 257 Topic: Backpropagation
# Index 258 Topic: Backpropagation
# Index 259 Topic: Backpropagation
# Index 260 Topic: Backpropagation
# Index 261 Topic: Backpropagation
# Index 262 Topic: Backpropagation
# Index 263 Topic: Backpropagation
# Index 264 Topic: Backpropagation
# Index 265 Topic: Backpropagation
# Index 266 Topic: Backpropagation
# Index 267 Topic: Backpropagation
# Index 268 Topic: Backpropagation
# Index 269 Topic: Backpropagation
# Index 270 Topic: Backpropagation
# Index 271 Topic: Backpropagation
# Index 272 Topic: Backpropagation
# Index 273 Topic: Backpropagation
# Index 274 Topic: Backpropagation
# Index 275 Topic: Backpropagation
# Index 276 Topic: Backpropagation
# Index 277 Topic: Backpropagation
# Index 278 Topic: Backpropagation
# Index 279 Topic: Backpropagation
# Index 280 Topic: Backpropagation
# Index 281 Topic: Backpropagation
# Index 282 Topic: Backpropagation
# Index 283 Topic: Backpropagation
# Index 284 Topic: Backpropagation
# Index 285 Topic: Backpropagation
# Index 286 Topic: Backpropagation
# Index 287 Topic: Backpropagation
# Index 288 Topic: Backpropagation
# Index 289 Topic: Foundations of Computer Vision and Convolutional Neural Networks
# Index 290 Topic: Foundations of Computer Vision and Convolutional Neural Networks
# Index 291 Topic: Foundations of Computer Vision and Convolutional Neural Networks
# Index 292 Topic: Foundations of Computer Vision and Convolutional Neural Networks
# Index 293 Topic: Foundations of Computer Vision and Convolutional Neural Networks
# Index 294 Topic: Foundations of Computer Vision and Convolutional Neural Networks
# Index 295 Topic: Foundations of Computer Vision and Convolutional Neural Networks
# Index 296 Topic: Foundations of Computer Vision and Convolutional Neural Networks
# Index 297 Topic: Foundations of Computer Vision and Convolutional Neural Networks
# Index 298 Topic: Foundations of Computer Vision and Convolutional Neural Networks
# Index 299 Topic: Foundations of Computer Vision and Convolutional Neural Networks
# Index 300 Topic: Foundations of Computer Vision and Convolutional Neural Networks
# Index 301 Topic: Foundations of Computer Vision and Convolutional Neural Networks
# Index 302 Topic: Foundations of Computer Vision and Convolutional Neural Networks
# Index 303 Topic: Foundations of Computer Vision and Convolutional Neural Networks
# Index 304 Topic: Foundations of Computer Vision and Convolutional Neural Networks
# Index 305 Topic: Foundations of Computer Vision and Convolutional Neural Networks
# Index 306 Topic: Foundations of Computer Vision and Convolutional Neural Networks
# Index 307 Topic: Foundations of Computer Vision and Convolutional Neural Networks
# Index 308 Topic: Foundations of Computer Vision and Convolutional Neural Networks
# Index 309 Topic: Foundations of Computer Vision and Convolutional Neural Networks
# Index 310 Topic: Foundations of Computer Vision and Convolutional Neural Networks
# Index 311 Topic: Foundations of Computer Vision and Convolutional Neural Networks
# Index 312 Topic: Foundations of Computer Vision and Convolutional Neural Networks
# Index 313 Topic: Foundations of Computer Vision and Convolutional Neural Networks
# Index 314 Topic: Foundations of Computer Vision and Convolutional Neural Networks
# Index 315 Topic: Foundations of Computer Vision and Convolutional Neural Networks
# Index 316 Topic: Foundations of Computer Vision and Convolutional Neural Networks
# Index 317 Topic: Foundations of Computer Vision and Convolutional Neural Networks
# Index 318 Topic: Foundations of Computer Vision and Convolutional Neural Networks
# Index 319 Topic: Foundations of Computer Vision and Convolutional Neural Networks
# Index 320 Topic: Foundations of Computer Vision and Convolutional Neural Networks
# Index 321 Topic: Foundations of Computer Vision and Convolutional Neural Networks
# Index 322 Topic: Foundations of Computer Vision and Convolutional Neural Networks
# Index 323 Topic: Foundations of Computer Vision and Convolutional Neural Networks
# Index 324 Topic: Foundations of Computer Vision and Convolutional Neural Networks
# Index 325 Topic: Foundations of Computer Vision and Convolutional Neural Networks
# Index 326 Topic: Foundations of Computer Vision and Convolutional Neural Networks
# Index 327 Topic: Foundations of Computer Vision and Convolutional Neural Networks
# Index 328 Topic: Foundations of Computer Vision and Convolutional Neural Networks
# Index 329 Topic: Foundations of Computer Vision and Convolutional Neural Networks
# Index 330 Topic: Foundations of Computer Vision and Convolutional Neural Networks
# Index 331 Topic: Foundations of Computer Vision and Convolutional Neural Networks
# Index 332 Topic: Foundations of Computer Vision and Convolutional Neural Networks
# Index 333 Topic: Foundations of Computer Vision and Convolutional Neural Networks
# Index 334 Topic: Foundations of Computer Vision and Convolutional Neural Networks
# Index 335 Topic: Foundations of Computer Vision and Convolutional Neural Networks
# Index 336 Topic: Foundations of Computer Vision and Convolutional Neural Networks
# Index 337 Topic: Transfer Learning for Computer Vision
# Index 338 Topic: Transfer Learning for Computer Vision
# Index 339 Topic: Transfer Learning for Computer Vision
# Index 340 Topic: Transfer Learning for Computer Vision
# Index 341 Topic: Transfer Learning for Computer Vision
# Index 342 Topic: Transfer Learning for Computer Vision
# Index 343 Topic: Transfer Learning for Computer Vision
# Index 344 Topic: Transfer Learning for Computer Vision
# Index 345 Topic: Transfer Learning for Computer Vision
# Index 346 Topic: Transfer Learning for Computer Vision
# Index 347 Topic: Transfer Learning for Computer Vision
# Index 348 Topic: Transfer Learning for Computer Vision
# Index 349 Topic: Transfer Learning for Computer Vision
# Index 350 Topic: Transfer Learning for Computer Vision
# Index 351 Topic: Transfer Learning for Computer Vision
# Index 352 Topic: Transfer Learning for Computer Vision
# Index 353 Topic: Transfer Learning for Computer Vision
# Index 354 Topic: Transfer Learning for Computer Vision
# Index 355 Topic: Transfer Learning for Computer Vision
# Index 356 Topic: Transfer Learning for Computer Vision
# Index 357 Topic: Transfer Learning for Computer Vision
# Index 358 Topic: Transfer Learning for Computer Vision
# Index 359 Topic: Transfer Learning for Computer Vision
# Index 360 Topic: Transfer Learning for Computer Vision
# Index 361 Topic: Transfer Learning for Computer Vision
# Index 362 Topic: Transfer Learning for Computer Vision
# Index 363 Topic: Transfer Learning for Computer Vision
# Index 364 Topic: Transfer Learning for Computer Vision
# Index 365 Topic: Transfer Learning for Computer Vision
# Index 366 Topic: Transfer Learning for Computer Vision
# Index 367 Topic: Transfer Learning for Computer Vision
# Index 368 Topic: Transfer Learning for Computer Vision
# Index 369 Topic: Transfer Learning for Computer Vision
# Index 370 Topic: Transfer Learning for Computer Vision
# Index 371 Topic: Transfer Learning for Computer Vision
# Index 372 Topic: Transfer Learning for Computer Vision
# Index 373 Topic: Transfer Learning for Computer Vision
# Index 374 Topic: Transfer Learning for Computer Vision
# Index 375 Topic: Transfer Learning for Computer Vision
# Index 376 Topic: Transfer Learning for Computer Vision
# Index 377 Topic: Transfer Learning for Computer Vision
# Index 378 Topic: Transfer Learning for Computer Vision
# Index 379 Topic: Transfer Learning for Computer Vision
# Index 380 Topic: Transfer Learning for Computer Vision
# Index 381 Topic: Transfer Learning for Computer Vision
# Index 382 Topic: Transfer Learning for Computer Vision
# Index 383 Topic: Transfer Learning for Computer Vision
# Index 384 Topic: Transfer Learning for Computer Vision
# Index 385 Topic: Image Segmentation and Object Detection
# Index 386 Topic: Image Segmentation and Object Detection
# Index 387 Topic: Image Segmentation and Object Detection
# Index 388 Topic: Image Segmentation and Object Detection
# Index 389 Topic: Image Segmentation and Object Detection
# Index 390 Topic: Image Segmentation and Object Detection
# Index 391 Topic: Image Segmentation and Object Detection
# Index 392 Topic: Image Segmentation and Object Detection
# Index 393 Topic: Image Segmentation and Object Detection
# Index 394 Topic: Image Segmentation and Object Detection
# Index 395 Topic: Image Segmentation and Object Detection
# Index 396 Topic: Image Segmentation and Object Detection
# Index 397 Topic: Image Segmentation and Object Detection
# Index 398 Topic: Image Segmentation and Object Detection
# Index 399 Topic: Image Segmentation and Object Detection
# Index 400 Topic: Image Segmentation and Object Detection
# Index 401 Topic: Image Segmentation and Object Detection
# Index 402 Topic: Image Segmentation and Object Detection
# Index 403 Topic: Image Segmentation and Object Detection
# Index 404 Topic: Image Segmentation and Object Detection
# Index 405 Topic: Image Segmentation and Object Detection
# Index 406 Topic: Image Segmentation and Object Detection
# Index 407 Topic: Image Segmentation and Object Detection
# Index 408 Topic: Image Segmentation and Object Detection
# Index 409 Topic: Image Segmentation and Object Detection
# Index 410 Topic: Image Segmentation and Object Detection
# Index 411 Topic: Image Segmentation and Object Detection
# Index 412 Topic: Image Segmentation and Object Detection
# Index 413 Topic: Image Segmentation and Object Detection
# Index 414 Topic: Image Segmentation and Object Detection
# Index 415 Topic: Image Segmentation and Object Detection
# Index 416 Topic: Image Segmentation and Object Detection
# Index 417 Topic: Image Segmentation and Object Detection
# Index 418 Topic: Image Segmentation and Object Detection
# Index 419 Topic: Image Segmentation and Object Detection
# Index 420 Topic: Image Segmentation and Object Detection
# Index 421 Topic: Image Segmentation and Object Detection
# Index 422 Topic: Image Segmentation and Object Detection
# Index 423 Topic: Image Segmentation and Object Detection
# Index 424 Topic: Image Segmentation and Object Detection
# Index 425 Topic: Image Segmentation and Object Detection
# Index 426 Topic: Image Segmentation and Object Detection
# Index 427 Topic: Image Segmentation and Object Detection
# Index 428 Topic: Image Segmentation and Object Detection
# Index 429 Topic: Image Segmentation and Object Detection
# Index 430 Topic: Image Segmentation and Object Detection
# Index 431 Topic: Image Segmentation and Object Detection
# Index 432 Topic: Image Segmentation and Object Detection
# Index 433 Topic: Data Pre-processing for Natural Language Processing Tasks
# Index 434 Topic: Data Pre-processing for Natural Language Processing Tasks
# Index 435 Topic: Data Pre-processing for Natural Language Processing Tasks
# Index 436 Topic: Data Pre-processing for Natural Language Processing Tasks
# Index 437 Topic: Data Pre-processing for Natural Language Processing Tasks
# Index 438 Topic: Data Pre-processing for Natural Language Processing Tasks
# Index 439 Topic: Data Pre-processing for Natural Language Processing Tasks
# Index 440 Topic: Data Pre-processing for Natural Language Processing Tasks
# Index 441 Topic: Data Pre-processing for Natural Language Processing Tasks
# Index 442 Topic: Data Pre-processing for Natural Language Processing Tasks
# Index 443 Topic: Data Pre-processing for Natural Language Processing Tasks
# Index 444 Topic: Data Pre-processing for Natural Language Processing Tasks
# Index 445 Topic: Data Pre-processing for Natural Language Processing Tasks
# Index 446 Topic: Data Pre-processing for Natural Language Processing Tasks
# Index 447 Topic: Data Pre-processing for Natural Language Processing Tasks
# Index 448 Topic: Data Pre-processing for Natural Language Processing Tasks
# Index 449 Topic: Data Pre-processing for Natural Language Processing Tasks
# Index 450 Topic: Data Pre-processing for Natural Language Processing Tasks
# Index 451 Topic: Data Pre-processing for Natural Language Processing Tasks
# Index 452 Topic: Data Pre-processing for Natural Language Processing Tasks
# Index 453 Topic: Data Pre-processing for Natural Language Processing Tasks
# Index 454 Topic: Data Pre-processing for Natural Language Processing Tasks
# Index 455 Topic: Data Pre-processing for Natural Language Processing Tasks
# Index 456 Topic: Data Pre-processing for Natural Language Processing Tasks
# Index 457 Topic: Data Pre-processing for Natural Language Processing Tasks
# Index 458 Topic: Data Pre-processing for Natural Language Processing Tasks
# Index 459 Topic: Data Pre-processing for Natural Language Processing Tasks
# Index 460 Topic: Data Pre-processing for Natural Language Processing Tasks
# Index 461 Topic: Data Pre-processing for Natural Language Processing Tasks
# Index 462 Topic: Data Pre-processing for Natural Language Processing Tasks
# Index 463 Topic: Data Pre-processing for Natural Language Processing Tasks
# Index 464 Topic: Data Pre-processing for Natural Language Processing Tasks
# Index 485 Topic: Bag of Words Approach and Word Embedding
# Index 486 Topic: Bag of Words Approach and Word Embedding
# Index 487 Topic: Bag of Words Approach and Word Embedding
# Index 488 Topic: Bag of Words Approach and Word Embedding
# Index 489 Topic: Bag of Words Approach and Word Embedding
# Index 490 Topic: Bag of Words Approach and Word Embedding
# Index 491 Topic: Bag of Words Approach and Word Embedding
# Index 492 Topic: Bag of Words Approach and Word Embedding
# Index 493 Topic: Bag of Words Approach and Word Embedding
# Index 494 Topic: Bag of Words Approach and Word Embedding
# Index 495 Topic: Bag of Words Approach and Word Embedding
# Index 496 Topic: Bag of Words Approach and Word Embedding
# Index 497 Topic: Bag of Words Approach and Word Embedding
# Index 498 Topic: Bag of Words Approach and Word Embedding
# Index 499 Topic: Bag of Words Approach and Word Embedding
# Index 500 Topic: Bag of Words Approach and Word Embedding
# Index 501 Topic: Bag of Words Approach and Word Embedding
# Index 502 Topic: Bag of Words Approach and Word Embedding
# Index 503 Topic: Bag of Words Approach and Word Embedding
# Index 504 Topic: Bag of Words Approach and Word Embedding
# Index 505 Topic: Bag of Words Approach and Word Embedding
# Index 506 Topic: Bag of Words Approach and Word Embedding
# Index 507 Topic: Bag of Words Approach and Word Embedding
# Index 508 Topic: Bag of Words Approach and Word Embedding
# Index 509 Topic: Bag of Words Approach and Word Embedding
# Index 510 Topic: Bag of Words Approach and Word Embedding
# Index 511 Topic: Bag of Words Approach and Word Embedding
# Index 512 Topic: Bag of Words Approach and Word Embedding
# Index 513 Topic: Bag of Words Approach and Word Embedding
# Index 514 Topic: Bag of Words Approach and Word Embedding
# Index 515 Topic: Bag of Words Approach and Word Embedding
# Index 516 Topic: Bag of Words Approach and Word Embedding

# %% [markdown]
# ## mistral-small3.2:latest

# %%
import csv
model = "mistral-small3.2:latest"
# Iterate over all sheets in the workbook
for sheet_name in wb.sheetnames:
    ws = wb[sheet_name]
    print(f"\nSheet: {sheet_name}")
    with open(f"{sheet_name}_{model}.csv", "w", newline="") as file:
        writer = csv.writer(file)
    
        for row in ws.iter_rows(min_row=2, max_col=4, max_row = 715):
            index = row[0].value  
            prompt = row[1].value 
            col_b_cell = row[1] if len(row) > 1 else None  
            prompt = get_merged_cell_value(ws, col_b_cell) if col_b_cell else None
            question = row[3].value  
            topic = [topic for topic in TOPICS if topic in prompt][0]
            print(f"Index {index} Topic: {topic}")
            temp = []
            for metric in metrics:
                temp.append(llm_inference(question,topic,metric, model = model))
            temp = clean_multi_task_outputs(temp)
            writer.writerow(temp)

# %% [markdown]
# ## gpt-oss:latest

# %%
import csv
model = "gpt-oss:latest"
# Iterate over all sheets in the workbook
for sheet_name in wb.sheetnames:
    ws = wb[sheet_name]
    print(f"\nSheet: {sheet_name}")
    with open(f"{sheet_name}_{model}.csv", "w", newline="") as file:
        writer = csv.writer(file)
    
        for row in ws.iter_rows(min_row=2, max_col=4, max_row = 715):
            index = row[0].value  
            prompt = row[1].value 
            col_b_cell = row[1] if len(row) > 1 else None  
            prompt = get_merged_cell_value(ws, col_b_cell) if col_b_cell else None
            question = row[3].value  
            topic = [topic for topic in TOPICS if topic in prompt][0]
            print(f"Index {index} Topic: {topic}")
            temp = []
            for metric in metrics:
                temp.append(llm_inference(question,topic,metric, model = model))
            temp = clean_multi_task_outputs(temp)
            writer.writerow(temp)
# Out:
# Index 582 Topic: Neural Machine Translation using Transformers
# Index 583 Topic: Neural Machine Translation using Transformers
# Index 584 Topic: Neural Machine Translation using Transformers
# Index 585 Topic: Neural Machine Translation using Transformers
# Index 586 Topic: Neural Machine Translation using Transformers
# Index 587 Topic: Neural Machine Translation using Transformers
# Index 588 Topic: Neural Machine Translation using Transformers

# %% [markdown]
# ## llama3.2:latest

# %%
import csv
model = "llama3.2:latest"
# Iterate over all sheets in the workbook
for sheet_name in wb.sheetnames:
    ws = wb[sheet_name]
    print(f"\nSheet: {sheet_name}")
    with open(f"{sheet_name}_{model}.csv", "w", newline="") as file:
        writer = csv.writer(file)
    
        for row in ws.iter_rows(min_row=2, max_col=4, max_row = 715):
            index = row[0].value  
            prompt = row[1].value 
            col_b_cell = row[1] if len(row) > 1 else None  
            prompt = get_merged_cell_value(ws, col_b_cell) if col_b_cell else None
            question = row[3].value  
            topic = [topic for topic in TOPICS if topic in prompt][0]
            print(f"Index {index} Topic: {topic}")
            temp = []
            for metric in metrics:
                temp.append(llm_inference(question,topic,metric, model = model))
            print(model)
            temp = clean_multi_task_outputs(temp)
            writer.writerow(temp)

# %% [markdown]
# ## phi4-mini:latest

# %%
import csv
model = "phi4-mini:latest"
# Iterate over all sheets in the workbook
for sheet_name in wb.sheetnames:
    ws = wb[sheet_name]
    print(f"\nSheet: {sheet_name}")
    with open(f"{sheet_name}_{model}.csv", "w", newline="") as file:
        writer = csv.writer(file)
    
        for row in ws.iter_rows(min_row=2, max_col=4, max_row = 715):
            index = row[0].value  
            prompt = row[1].value 
            col_b_cell = row[1] if len(row) > 1 else None  
            prompt = get_merged_cell_value(ws, col_b_cell) if col_b_cell else None
            question = row[3].value  
            topic = [topic for topic in TOPICS if topic in prompt][0]
            print(f"Index {index} Topic: {topic}")
            temp = []
            for metric in metrics:
                temp.append(llm_inference(question,topic,metric, model = model))
            print(model)
            temp = clean_multi_task_outputs(temp)
            writer.writerow(temp)

# %% [markdown]
# ## gemma3:latest

# %%
import csv
model = "gemma3:latest"
# Iterate over all sheets in the workbook
for sheet_name in wb.sheetnames:
    ws = wb[sheet_name]
    print(f"\nSheet: {sheet_name}")
    with open(f"{sheet_name}_{model}.csv", "w", newline="") as file:
        writer = csv.writer(file)
    
        for row in ws.iter_rows(min_row=2, max_col=4, max_row = 715):
            index = row[0].value  
            prompt = row[1].value 
            col_b_cell = row[1] if len(row) > 1 else None  
            prompt = get_merged_cell_value(ws, col_b_cell) if col_b_cell else None
            question = row[3].value  
            topic = [topic for topic in TOPICS if topic in prompt][0]
            print(f"Index {index} Topic: {topic}")
            temp = []
            for metric in metrics:
                temp.append(llm_inference(question,topic,metric, model = model))
            print(model)
            temp = clean_multi_task_outputs(temp)
            writer.writerow(temp)

# %% [markdown]
# ## phi4:latest

# %%
import csv
model = "phi4:latest"
# Iterate over all sheets in the workbook
for sheet_name in wb.sheetnames:
    ws = wb[sheet_name]
    print(f"\nSheet: {sheet_name}")
    with open(f"{sheet_name}_{model}.csv", "w", newline="") as file:
        writer = csv.writer(file)
    
        for row in ws.iter_rows(min_row=2, max_col=4, max_row = 715):
            index = row[0].value  
            prompt = row[1].value 
            col_b_cell = row[1] if len(row) > 1 else None  
            prompt = get_merged_cell_value(ws, col_b_cell) if col_b_cell else None
            question = row[3].value  
            topic = [topic for topic in TOPICS if topic in prompt][0]
            print(f"Index {index} Topic: {topic}")
            temp = []
            for metric in metrics:
                temp.append(llm_inference(question,topic,metric, model = model))
            print(model)
            temp = clean_multi_task_outputs(temp)
            writer.writerow(temp)

# %% [markdown]
# # No cleaning

# %%
import csv
model = "deepseek-r1:14b"
# Iterate over all sheets in the workbook
for sheet_name in wb.sheetnames:
    ws = wb[sheet_name]
    print(f"\nSheet: {sheet_name}")
    with open(f"{sheet_name}_{model}.csv", "w", newline="") as file:
        writer = csv.writer(file)
    
        for row in ws.iter_rows(min_row=2, max_col=4, max_row = 715):
            index = row[0].value  
            prompt = row[1].value 
            col_b_cell = row[1] if len(row) > 1 else None  
            prompt = get_merged_cell_value(ws, col_b_cell) if col_b_cell else None
            question = row[3].value  
            topic = [topic for topic in TOPICS if topic in prompt][0]
            print(f"Index {index} Topic: {topic}")
            temp = []
            for metric in metrics:
                temp.append(llm_inference(question,topic,metric, model = model))
            # print(model)
            # temp = clean_multi_task_outputs(temp)
            writer.writerow(temp)

# %% [markdown]
# ## mistral-small3.2:latest

# %%
import csv
model = "mistral-small3.2:latest "
# Iterate over all sheets in the workbook
for sheet_name in wb.sheetnames:
    ws = wb[sheet_name]
    print(f"\nSheet: {sheet_name}")
    with open(f"{sheet_name}_{model}.csv", "w", newline="") as file:
        writer = csv.writer(file)
    
        for row in ws.iter_rows(min_row=2, max_col=4, max_row = 715):
            index = row[0].value  
            prompt = row[1].value 
            col_b_cell = row[1] if len(row) > 1 else None  
            prompt = get_merged_cell_value(ws, col_b_cell) if col_b_cell else None
            question = row[3].value  
            topic = [topic for topic in TOPICS if topic in prompt][0]
            print(f"Index {index} Topic: {topic}")
            temp = []
            for metric in metrics:
                temp.append(llm_inference(question,topic,metric, model = model))
            # print(model)
            # temp = clean_multi_task_outputs(temp)
            writer.writerow(temp)

# %% [markdown]
# ## llama3.3:latest

# %%
import csv
model = "llama3.3:latest"
# Iterate over all sheets in the workbook
for sheet_name in wb.sheetnames:
    ws = wb[sheet_name]
    print(f"\nSheet: {sheet_name}")
    with open(f"{sheet_name}_{model}.csv", "w", newline="") as file:
        writer = csv.writer(file)
    
        for row in ws.iter_rows(min_row=2, max_col=4, max_row = 715):
            index = row[0].value  
            prompt = row[1].value 
            col_b_cell = row[1] if len(row) > 1 else None  
            prompt = get_merged_cell_value(ws, col_b_cell) if col_b_cell else None
            question = row[3].value  
            topic = [topic for topic in TOPICS if topic in prompt][0]
            print(f"Index {index} Topic: {topic}")
            temp = []
            for metric in metrics:
                temp.append(llm_inference(question,topic,metric, model = model))
            # print(model)
            # temp = clean_multi_task_outputs(temp)
            writer.writerow(temp)

# %% [markdown]
# ## mistral-large:latest

# %%
import csv
model = "mistral-large:latest"
# Iterate over all sheets in the workbook
for sheet_name in wb.sheetnames:
    if sheet_name in ['PS1','PS2','PS3']:
        continue
    ws = wb[sheet_name]
    print(f"\nSheet: {sheet_name}")
    with open(f"{sheet_name}_{model}.csv", "w", newline="") as file:
        writer = csv.writer(file)
    
        for row in ws.iter_rows(min_row=2, max_col=4, max_row = 715):
            index = row[0].value  
            prompt = row[1].value 
            col_b_cell = row[1] if len(row) > 1 else None  
            prompt = get_merged_cell_value(ws, col_b_cell) if col_b_cell else None
            question = row[3].value  
            topic = [topic for topic in TOPICS if topic in prompt][0]
            print(f"Index {index} Topic: {topic}")
            temp = []
            for metric in metrics:
                temp.append(llm_inference(question,topic,metric, model = model))
            # print(model)
            # temp = clean_multi_task_outputs(temp)
            writer.writerow(temp)

# %% [markdown]
# ## gpt-oss:latest

# %%
import csv
model = "gpt-oss:latest"
# Iterate over all sheets in the workbook
for sheet_name in wb.sheetnames:
    ws = wb[sheet_name]
    print(f"\nSheet: {sheet_name}")
    with open(f"{sheet_name}_{model}.csv", "w", newline="") as file:
        writer = csv.writer(file)
    
        for row in ws.iter_rows(min_row=2, max_col=4, max_row = 715):
            index = row[0].value  
            prompt = row[1].value 
            col_b_cell = row[1] if len(row) > 1 else None  
            prompt = get_merged_cell_value(ws, col_b_cell) if col_b_cell else None
            question = row[3].value  
            topic = [topic for topic in TOPICS if topic in prompt][0]
            print(f"Index {index} Topic: {topic}")
            temp = []
            for metric in metrics:
                temp.append(llm_inference(question,topic,metric, model = model))
            # print(model)
            # temp = clean_multi_task_outputs(temp)
            writer.writerow(temp)
